# %% [markdown]
# <a href="https://colab.research.google.com/github/teukufadhil2010-sudo/Dasar-X-2627/blob/main/X_PPLG_TEUKU_MUHAMMAD_FADHIL_Tugas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tugas 1 Praktik Membuat Tipe data dan Variabel
#
# Nama Kelompok: NEXACODE
# Nama Anggota:
# 1. Teuku Muhammad Fadhil
# 2. Aghnan aiszar kamaludin
# 3. Nur Mawadah
# 4. syafira meidina Syarif
# 5. Alyaa Rahma Thalita
# 6. raisya putri darmawan
# 7. Davi Ramadhan Pratama

# %%
# %%writefile praktik_variabel.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
#     // Deklarasi Variabel dan Tipe Data
#     string namaBarang = "Laptop Asus";
#     int jumlah = 2;
#     float harga = 7500000.50;
#     char kategori = 'A';
#     bool tersedia = true;
#
#     // Menampilkan Output ke Layar
#     cout << "=== DATA INVENTARIS ===" << endl;
#     cout << "Nama Barang : " << namaBarang << endl;
#     cout << "Kategori    : " << kategori << endl;
#     cout << "Jumlah      : " << jumlah << endl;
#     cout << "Harga       : Rp " << harga << endl;
#     cout << "Tersedia    : " << tersedia << " (1 = Ya, 0 = Tidak)" << endl;
#     cout << "=======================" << endl;
#
#     return 0;
# }
# Out:
# Writing praktik_variabel.cpp

# %%
# !g++ praktik_variabel.cpp -o praktik_variabel

# %%
# !./praktik_variabel
# Out:
# === DATA INVENTARIS ===
# Nama Barang : Laptop Asus
# Kategori    : A
# Jumlah      : 2
# Harga       : Rp 7.5e+06
# Tersedia    : 1 (1 = Ya, 0 = Tidak)
# ...
