# %% [markdown]
# <a href="https://colab.research.google.com/github/teukufadhil2010-sudo/Dasar-X-2627/blob/main/tugas_program_menghitung_luas_perswegi_panjang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TUGAS MEMBUAT MENGHITUNG LUAS PERSEGI PANJANG
#
# kelompok : nexacode
# 1. fadhil
# 2. aghnan
# 3. davi
# 4. nurma
# 5. dina
# 6. alya
# 7. raisya

# %%
# !g++ --version
# Out:
# g++ (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%writefile luaspersegipanjang.cpp
# #include <iostream>
# using namespace std;
#
# int main() {
#     float panjang, lebar, luas;
#
#     cout << "masukan panjang: ";
#     cin >> panjang;
#     cout << "masukan lebar: ";
#     cin >> lebar;
#
#     luas = panjang * lebar;
#     cout << "luas persegi panjang = " << luas << endl;
#
#     return 0;
# }
# Out:
# Overwriting luaspersegipanjang.cpp

# %%
# !g++ luaspersegipanjang.cpp -o main

# %%
! ./main
# Out:
# masukan panjang:
